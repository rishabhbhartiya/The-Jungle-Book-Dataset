# %%
import pandas as pd

# %%
dataset = pd.read_csv('/content/THE JUNGLE BOOK.csv')

# %%
dataset.head(4)
# Out:
#    Unnamed: 0  0_x                                                  1  \
# 0           0    1  "Mowgli Comes into the Jungle / Mowgli Comes t...
# 1           1    2  "The Birth of Wolf-Boy Mowgli / Mowgli Comes t...
# 2           2    3                                  "Alexander's Son"
# 3           3    4                                   "The Jungle Law"
#
#                 2                  3                             4  \
# 0    Kimio Yabuki  Nobuyuki Fujimoto   October 2, 1989(1989-10-02)
# 1  Fumio Kurokawa      Mami Watanabe   October 9, 1989(1989-10-09)
# 2       Koji Suda      Mami Watanabe  October 16, 1989(1989-10-16)
# 3  Takeo Kitahara  Nobuyuki Fujimoto  October 23, 1989(1989-10-23)
#
#                                                  0_y
# 0  \n\n    Mowgli is the infant son of a scientis...
# 1  \n\n    Mowgli has a serious problem: he canno...
# 2  \n\n    Mowgli is desperate because Lala has h...
# 3  \n\n    Some aspects of the jungle life are in...

# %%
dataset.rename(columns={"0_x": "EPISODE_NUMBER", "1": "EPISODE TITLE", "2": "DIRECTED BY", "3": "WRITTEN BY", "4": "AIRED DATE", "0_y": "DESCRIPTION"}, inplace=True)

# %%
dataset.drop(columns=["Unnamed: 0"], inplace=True)

# %%
dataset.head(4)
# Out:
#    EPISODE_NUMBER                                      EPISODE TITLE  \
# 0               1  "Mowgli Comes into the Jungle / Mowgli Comes t...
# 1               2  "The Birth of Wolf-Boy Mowgli / Mowgli Comes t...
# 2               3                                  "Alexander's Son"
# 3               4                                   "The Jungle Law"
#
#       DIRECTED BY         WRITTEN BY                    AIRED DATE  \
# 0    Kimio Yabuki  Nobuyuki Fujimoto   October 2, 1989(1989-10-02)
# 1  Fumio Kurokawa      Mami Watanabe   October 9, 1989(1989-10-09)
# 2       Koji Suda      Mami Watanabe  October 16, 1989(1989-10-16)
# 3  Takeo Kitahara  Nobuyuki Fujimoto  October 23, 1989(1989-10-23)
#
#                                          DESCRIPTION
# 0  \n\n    Mowgli is the infant son of a scientis...
# 1  \n\n    Mowgli has a serious problem: he canno...
# 2  \n\n    Mowgli is desperate because Lala has h...
# 3  \n\n    Some aspects of the jungle life are in...

# %%
def remove_unwanted_characters(text):
    modified_text = text.replace('\n\n', '').replace('"', '')
    return modified_text

# %%
dataset["DESCRIPTION"] = dataset["DESCRIPTION"].apply(remove_unwanted_characters)

# %%
dataset["AIRED DATE"][3]
# Out:
# 'October\xa023,\xa01989(1989-10-23)'

# %%
def process_date(date_string):
  cleaned_date = date_string.split('(')
  return cleaned_date[1]

# %%
dataset["AIRED DATE"] = dataset["AIRED DATE"].apply(process_date)

# %%
def remove_parenthesis(date_string):
  cleaned_date = date_string.replace(')', '')
  return cleaned_date

# %%
dataset["AIRED DATE"] = dataset["AIRED DATE"].apply(remove_parenthesis)

# %%
def remove_directedby(text):
  if 'Directed by' in text:
    split_text = text.replace('Directed by: ', '')
    return split_text
  else:
    return text

# %%
dataset["DIRECTED BY"] = dataset["DIRECTED BY"].apply(remove_directedby)

# %%
dataset[4:10]
# Out:
#    EPISODE_NUMBER                                 EPISODE TITLE  \
# 4               5              "The New Friends / A New Friend"
# 5               6             "Solitary Kichi / Kichi is Alone"
# 6               7                               "The Cold Fang"
# 7               8                               "Sorry, Baloo!"
# 8               9                  "More Precious than the Law"
# 9              10  "The Lone Wolf Visitor / An Old Wolf Visits"
#
#                                        DIRECTED BY         WRITTEN BY  \
# 4  Shinji TakahashiStoryboarded by: Takeo Kitahara  Nobuyuki Fujimoto
# 5                                   Junichi Sakata  Nobuyuki Fujimoto
# 6          Akira ShimizuStoryboarded by: Koji Suda  Nobuyuki Fujimoto
# 7  Shinji TakahashiStoryboarded by: Shigeto Makino  Nobuyuki Fujimoto
# 8  Kazuya MiyazakiStoryboarded by: Hidetoshi Omori      Mami Watanabe
# 9    Shigeru YamazakiStoryboarded by: Shigeo Koshi  Nobuyuki Fujimoto
#
#    AIRED DATE                                        DESCRIPTION
# 4  1989-10-30      Life in the jungle is easier for those who...
# 5  1989-11-06      Kichi wants to spend all his time with Mow...
# 6  1989-11-13      Sometimes Mowgli does not heed Baloo's tea...
# 7  1989-11-20      Mowgli has been trapped. While he struggle...
# 8  1989-11-27      Akru breaks the law of the pack, places Mo...
# 9  1989-12-04      Times are hard for the wolves in the jungl...

# %%
def separate_storyboarded(text):
  if 'Storyboarded by' in text:
    split_text = text.replace('Storyboarded by:', ',')
    return split_text
  else:
    return text

# %%
separate_storyboarded("Shinji TakahashiStoryboarded by: Takeo Kitahara")
# Out:
# 'Shinji Takahashi, Takeo Kitahara'

# %%
dataset["DIRECTED BY"] = dataset["DIRECTED BY"].apply(separate_storyboarded)

# %%
# Apply the splitting logic only if a comma is present
for index, row in dataset.iterrows():
    if ',' in row['DIRECTED BY']:
        split_values = row['DIRECTED BY'].split(',')
        dataset.at[index, 'DIRECTED BY'] = split_values[0]
        dataset.at[index, 'STORY BOARDED'] = split_values[1] if len(split_values) > 1 else ''
    else:
        dataset.at[index, 'STORY BOARDED'] = 'None'

# %%
dataset.head(4)
# Out:
#    EPISODE_NUMBER                                      EPISODE TITLE  \
# 0               1  "Mowgli Comes into the Jungle / Mowgli Comes t...
# 1               2  "The Birth of Wolf-Boy Mowgli / Mowgli Comes t...
# 2               3                                  "Alexander's Son"
# 3               4                                   "The Jungle Law"
#
#       DIRECTED BY         WRITTEN BY  AIRED DATE  \
# 0    Kimio Yabuki  Nobuyuki Fujimoto  1989-10-02
# 1  Fumio Kurokawa      Mami Watanabe  1989-10-09
# 2       Koji Suda      Mami Watanabe  1989-10-16
# 3  Takeo Kitahara  Nobuyuki Fujimoto  1989-10-23
#
#                                          DESCRIPTION STORY BOARDED
# 0      Mowgli is the infant son of a scientist wh...          None
# 1      Mowgli has a serious problem: he cannot ru...          None
# 2      Mowgli is desperate because Lala has hidde...          None
# 3      Some aspects of the jungle life are incomp...          None

# %%
new_order = ["EPISODE_NUMBER", "EPISODE TITLE", "DIRECTED BY", "WRITTEN BY", "STORY BOARDED", "DESCRIPTION", "AIRED DATE"]
dataset = dataset[new_order]

# %%
dataset.to_csv("MOWGLI: THE JUNGLE BOOK.csv")
